# %%
import pandas as pd

# %%
df = pd.read_csv("recent_earnings.csv")
df
# Out:
#      Symbol                              Name  Current Price  % Change  \
# 0      EDSA     Edesa Biotech - Common Shares           4.83    0.0343
# 1      ASYS                    Amtech Systems           3.44   -0.1527
# 2       FTS              Fortis Common Shares          39.06    0.0031
# 3      CTLT                          Catalent          56.71    0.0028
# 4       NWL                     Newell Brands           6.85   -0.1893
# ...     ...                               ...            ...       ...
# 4480   BYRN                Byrna Technologies           9.84    0.1069
# 4481    DPZ                    Domino's Pizza         425.09   -0.0035
# 4482   RMCF  Rocky Mountain Chocolate Factory           4.05    0.0050
# 4483   DOGZ                    Dogness (Intl)           3.53    0.0665
# 4484   ARTW       Art's-Way Manufacturing Co.           1.97   -0.0574
#
#       Avg Stock Volume  Avg Option Volume        Date  Implied Move  \
# ...

# %%
from polygon import RESTClient

client = RESTClient("bhWcHFPPWYcK2t7aQDdCPOfguDEgDxB8")

aggs = []
for a in client.list_aggs(
    "AAPL",
    1,
    "minute",
    "2022-01-01",
    "2023-02-03",
    limit=50000,
):
    aggs.append(a)

print(aggs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from polygon import RESTClient
#       3 client = RESTClient("bhWcHFPPWYcK2t7aQDdCPOfguDEgDxB8")
#       5 aggs = []
#
# ModuleNotFoundError: No module named 'polygon'
